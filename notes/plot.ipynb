# %%
import numpy as np
import matplotlib.pyplot as plt

data_fdtd1 = np.loadtxt('../build/check_fdtd1.txt')
data_bem1 = np.loadtxt('../build/check_bem1.txt')
data_fdtd2 = np.loadtxt('../build/check_fdtd2.txt')
data_bem2 = np.loadtxt('../build/check_bem2.txt')

plt.figure(figsize=(15, 5))
plt.plot(data_fdtd1)
plt.plot(data_bem1)
plt.plot(data_fdtd2)
plt.plot(data_bem2)
plt.legend(['fdtd1', 'bem1', 'fdtd2', 'bem2'])
