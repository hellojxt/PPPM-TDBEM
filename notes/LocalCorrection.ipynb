# %%
import numpy as np
import matplotlib.pyplot as plt

data_fdtd = np.loadtxt('../build/tests/check_fdtd.txt')
data_bem = np.loadtxt('../build/tests/check_bem.txt')

plt.figure(figsize=(15, 5))
plt.plot(data_fdtd)
plt.plot(data_bem)
plt.legend(['fdtd', 'bem'])
