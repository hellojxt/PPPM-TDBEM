# %%
import numpy as np
import matplotlib.pyplot as plt

data1 = np.loadtxt('../build/particle_far_field.txt')
data2 = np.loadtxt('../build/particle_far_field_from_solver.txt')

plt.figure(figsize=(15, 5))
plt.plot(data1)
plt.plot(data2)
plt.legend(['analytical', 'from solver'])

# %%
data1 = np.loadtxt('../build/particle_near_field.txt')
data2 = np.loadtxt('../build/particle_near_field_from_solver.txt')

plt.figure(figsize=(15, 5))
plt.plot(data1)
plt.plot(data2)
plt.legend(['analytical', 'from solver'])
