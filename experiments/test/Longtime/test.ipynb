# %%
import numpy as np

import matplotlib.pyplot as plt

data1 = np.loadtxt('pppm.txt')
data2 = np.loadtxt('gt.txt')
x = np.arange(0, len(data1), 1)
plt.plot(x, data1, label='pppm')
plt.plot(x, data2, label='gt')
plt.legend()
plt.show()
